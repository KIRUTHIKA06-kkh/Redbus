# %%
import pandas as pd
import numpy as np

# %% [markdown]
# All state details

# %%
df_ap=pd.read_csv('all_bus_details_ap.csv')
df_k=pd.read_csv('all_bus_details_k.csv')
df_t=pd.read_csv('all_bus_details_t.csv')
df_kad=pd.read_csv('all_bus_details_kad.csv')
df_r=pd.read_csv('all_bus_details_r.csv')
df_sb=pd.read_csv('all_bus_details_sb.csv')
df_hp=pd.read_csv('all_bus_details_hp.csv')
df_a=pd.read_csv('all_bus_details_a.csv')
df_up=pd.read_csv('all_bus_details_up.csv')
df_b=pd.read_csv('all_bus_details_b.csv')

# %%
redbus_df=pd.concat([df_ap,df_k,df_t,df_kad,df_r,df_sb,df_hp,df_a,df_up,df_b],ignore_index=True)
redbus_df
# Out:
#                         Route_name  \
# 0          Hyderabad to Vijayawada
# 1          Hyderabad to Vijayawada
# 2          Hyderabad to Vijayawada
# 3          Hyderabad to Vijayawada
# 4          Hyderabad to Vijayawada
# ...                            ...
# 6768  Gopalganj (Bihar) to Lucknow
# 6769  Gopalganj (Bihar) to Lucknow
# 6770  Gopalganj (Bihar) to Lucknow
# 6771  Gopalganj (Bihar) to Lucknow
# 6772  Gopalganj (Bihar) to Lucknow
#
#                                              Route_link  \
# 0     https://www.redbus.in/bus-tickets/hyderabad-to...
# 1     https://www.redbus.in/bus-tickets/hyderabad-to...
# 2     https://www.redbus.in/bus-tickets/hyderabad-to...
# 3     https://www.redbus.in/bus-tickets/hyderabad-to...
# 4     https://www.redbus.in/bus-tickets/hyderabad-to...
# ...                                                 ...
# 6768  https://www.redbus.in/bus-tickets/gopalganj-to...
# 6769  https://www.redbus.in/bus-tickets/gopalganj-to...
# ...

# %%
redbus_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6773 entries, 0 to 6772
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Route_name         6773 non-null   object
#  1   Route_link         6773 non-null   object
#  2   Bus_name           6773 non-null   object
#  3   Bus_type           6773 non-null   object
#  4   Departing_time     6773 non-null   object
#  5   Duration           6773 non-null   object
#  6   Reaching_time      6773 non-null   object
#  7   Star_rating        6773 non-null   float64
#  8   Price              6773 non-null   float64
#  9   Seat_availability  6773 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 529.3+ KB

# %%
redbus_df["Price"]=redbus_df["Price"].str.replace("INR","")
redbus_df["Price"]=redbus_df["Price"].astype(float)
redbus_df["Price"].fillna(0)
# Out:
# 0        469.0
# 1        720.0
# 2        412.0
# 3        639.0
# 4        595.0
#          ...
# 6768     999.0
# 6769    1749.0
# 6770    1050.0
# 6771    1079.0
# 6772    1349.0
# Name: Price, Length: 6773, dtype: float64

# %%
redbus_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6773 entries, 0 to 6772
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Route_name         6773 non-null   object
#  1   Route_link         6773 non-null   object
#  2   Bus_name           6773 non-null   object
#  3   Bus_type           6773 non-null   object
#  4   Departing_time     6773 non-null   object
#  5   Duration           6773 non-null   object
#  6   Reaching_time      6773 non-null   object
#  7   Star_rating        6773 non-null   float64
#  8   Price              6773 non-null   object
#  9   Seat_availability  6773 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 529.3+ KB

# %%
redbus_df=redbus_df.replace({np.nan:None})

# %%
redbus_df.to_csv('redbus_df.csv',index=False)

# %% [markdown]
# Create Table by Postgres SQL

# %%
import pandas as pd
from sqlalchemy import create_engine

data=pd.read_csv('redbus_df.csv')

host="localhost"
port="5432"
database="sqldb"
user="postgres"
password="181506"

engine_string = f"postgresql://{user}:{password}@{host}:{port}/{database}"

engine = create_engine(engine_string)

table_name = "project_table"

data.to_sql(table_name, engine,if_exists='replace', index=False)  

print("Data successfully pushed to PostgreSQL table!")
# Out:
# Data successfully pushed to PostgreSQL table!
